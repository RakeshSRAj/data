# %% [markdown]
# <a href="https://colab.research.google.com/github/RakeshSRAj/data/blob/main/summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch torchvision torchaudio
# !pip install tf-keras
from transformers import pipeline

# Load pre-trained summarization pipeline
summarization_pipeline = pipeline("summarization")

# Function to summarize text
def summarize_text(text, max_length=100, min_length=30):
    summary = summarization_pipeline(text, max_length=max_length, min_length=min_length, do_sample=False)
    return summary[0]['summary_text']

# Example passage for summarization
long_text = (
    "Artificial intelligence is rapidly transforming various industries, "
    "enabling automation, improving efficiency, and enhancing decision-making processes. "
    "With the rise of machine learning and deep learning models, businesses can now process large amounts of data "
    "more effectively, uncover hidden patterns, and gain valuable insights. "
    "However, ethical concerns, data privacy, and bias in AI algorithms remain significant challenges. "
    "As technology advances, organizations and policymakers must collaborate to ensure responsible AI development and deployment."
)

# Obtain summarized text
summary_result = summarize_text(long_text)
print("Original Text:", long_text)
print("Summarized Text:", summary_result)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 32.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# using text file
# !pip install transformers torch torchvision torchaudio
# !pip install tf-keras
from transformers import pipeline



# Load pre-trained summarization pipeline
summarization_pipeline = pipeline("summarization")

# Function to summarize text
def summarize_text(text, max_length=100, min_length=30):
    summary = summarization_pipeline(text, max_length=max_length, min_length=min_length, do_sample=False)
    return summary[0]['summary_text']

from google.colab import drive
file_path = '/content/drive/My Drive/summary.txt'

try:
    # Read the text from the file
    with open(file_path, 'r', encoding='utf-8') as f:
        input_text = f.read()


except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}")
except Exception as e:
    print(f"An error occurred: {e}")

summary_result = summarize_text(input_text)
print("Original Text:", input_text)
print("Summarized Text:", summary_result)
# Out:
# ...
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# An error occurred: [Errno 107] Transport endpoint is not connected: '/content/drive/My Drive/summary.txt'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3775424548> in <cell line: 0>()
#      28     print(f"An error occurred: {e}")
#      29
# ---> 30 summary_result = summarize_text(input_text)
#      31 print("Original Text:", input_text)
#      32 print("Summarized Text:", summary_from_file)
#
# NameError: name 'input_text' is not defined

# %% [markdown]
# # Task
# Summarize the text content of the PDF file "summary.pdf".

# %% [markdown]
# ## Install necessary libraries
#
# ### Subtask:
# Install libraries for reading PDF files.

# %% [markdown]
# **Reasoning**:
# The subtask is to install the PyMuPDF library. I will use the `pip install` command in a code block to install the library.

# %%
# !pip install PyMuPDF

# %% [markdown]
# ## Read pdf
#
# ### Subtask:
# Extract text content from the specified PDF file.

# %% [markdown]
# **Reasoning**:
# Extract text content from the specified PDF file using the `fitz` library.

# %%
import fitz

file_path = '/content/drive/My Drive/summary.pdf'
pdf_text = ""

try:
    with fitz.open(file_path) as doc:
        for page in doc:
            pdf_text += page.get_text()

except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: no such file: '/content/drive/My Drive/summary.pdf'

# %% [markdown]
# ## Read pdf
#
# ### Subtask:
# Extract text content from the specified PDF file.

# %% [markdown]
# ## Read pdf
#
# ### Subtask:
# Extract text content from the specified PDF file.

# %% [markdown]
# **Reasoning**:
# Attempt to extract text from the PDF file again, ensuring the correct file path is used and handling potential errors.

# %%
import fitz

file_path = '/content/drive/My Drive/summary.pdf'
pdf_text = ""

try:
    with fitz.open(file_path) as doc:
        for page in doc:
            pdf_text += page.get_text()

except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: no such file: '/content/drive/My Drive/summary.pdf'

# %% [markdown]
# ## Read pdf
#
# ### Subtask:
# Extract text content from the specified PDF file.

# %% [markdown]
# **Reasoning**:
# Attempt to mount Google Drive and read the PDF file again, incorporating the necessary imports and error handling as specified in the instructions.

# %%
from google.colab import drive
import fitz

# Mount Google Drive
drive.mount('/content/drive')

file_path = '/content/drive/My Drive/summary.pdf'
pdf_text = ""

try:
    with fitz.open(file_path) as doc:
        for page in doc:
            pdf_text += page.get_text()

except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Reasoning**:
# Check if the pdf_text variable is not empty to confirm successful text extraction, and if so, print the extracted text. Otherwise, finish the task with failure as the file was not found.

# %%
if pdf_text:
    print("Successfully extracted text from the PDF.")
    print(pdf_text)
else:
    print("PDF text extraction failed.")
# Out:
# Successfully extracted text from the PDF.
# Chikmagalur is a hill station in Karnataka, a state in southwest India. To the north is Baba Budangiri,
# a mountain range in the Western Ghats, with 3 large caves said to be holy. Trails through forests and
# grasslands lead up to Mullayanagiri Peak. The cascading Hebbe Falls lie in an area of coffee
# plantations. The forested Bhadra Wildlife Sanctuary, northwest of Chikmagalur, is home to
# elephants, tigers and leopards.

# %% [markdown]
# ## Summarize text
#
# ### Subtask:
# Use the existing summarization function to summarize the extracted text.

# %% [markdown]
# **Reasoning**:
# Call the existing `summarize_text` function with the extracted text and store the result in a new variable.

# %%
summarized_pdf_text = summarize_text(pdf_text)
print("Summarized PDF Text:", summarized_pdf_text)
# Out:
# Summarized PDF Text:  Chikmagalur is a hill station in Karnataka, a state in southwest India . To the north is Baba Budangiri, a mountain range in the Western Ghats, with 3 large caves said to be holy . The cascading Hebbe Falls lie in an area of coffee plantations .

# %% [markdown]
# ## Display results
#
# ### Subtask:
# Print the original text and the summarized text.

# %% [markdown]
# **Reasoning**:
# Print the original and summarized text as requested.

# %%
print("Original PDF Text:", pdf_text)
print("Summarized PDF Text:", summarized_pdf_text)
# Out:
# Original PDF Text: Chikmagalur is a hill station in Karnataka, a state in southwest India. To the north is Baba Budangiri,
# a mountain range in the Western Ghats, with 3 large caves said to be holy. Trails through forests and
# grasslands lead up to Mullayanagiri Peak. The cascading Hebbe Falls lie in an area of coffee
# plantations. The forested Bhadra Wildlife Sanctuary, northwest of Chikmagalur, is home to
# elephants, tigers and leopards.
#
# Summarized PDF Text:  Chikmagalur is a hill station in Karnataka, a state in southwest India . To the north is Baba Budangiri, a mountain range in the Western Ghats, with 3 large caves said to be holy . The cascading Hebbe Falls lie in an area of coffee plantations .

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The required library for reading PDF files, `PyMuPDF`, was already installed.
# *   Initial attempts to access the PDF file at `/content/drive/My Drive/summary.pdf` resulted in a `FileNotFoundError`.
# *   Mounting Google Drive allowed the script to successfully locate and extract text from the "summary.pdf" file.
# *   The text content from the PDF was successfully extracted.
# *   The extracted text was successfully summarized using an existing `summarize_text` function.
# *   Both the original and summarized text were successfully printed.
#
# ### Insights or Next Steps
#
# *   Ensure the file path is correct and the necessary drive is mounted before attempting file operations to avoid `FileNotFoundError`.
# *   The task successfully extracted and summarized the PDF content, fulfilling the user's request.
